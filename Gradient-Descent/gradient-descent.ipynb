# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples = 4, n_features = 1, n_informative=1,n_targets = 1, noise=80,random_state = 13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='Red')

# %%
y_pred = ((78.35 * X) +0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'Red',label = 'OLS')
plt.plot(X,y_pred,color = '#00a65a', label='b=0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0
loss_slope = -2 * np.sum(y - m*X.ravel()-b)
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
lr = 0.1
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
b = b - step_size

# %%
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = '#00a65a', label='b= {}'.format(b))
plt.plot(X,y_pred,color = '#A3E4D7', label='b=0')
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel()-b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
step_size = loss_slope*lr

# %%
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = '#00a65a', label='b= {}'.format(b))
plt.plot(X,y_pred2,color = '#00a65a', label='b= {}'.format(b))

plt.plot(X,y_pred,color = '#A3E4D7', label='b=0')
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() -b )
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
step_size = loss_slope*lr

# %%
step_size
# Out:
# np.float64(-0.8371105363283675)

# %%
b = b-step_size

# %%
b
# Out:
# np.float64(25.95042662617943)

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = '#00a65a', label='b= {}'.format(b))
plt.plot(X,y_pred2,color = '#00a65a', label='b= {}'.format(b))
plt.plot(X,y_pred3,color = '#00a65a', label='b= {}'.format(b))

plt.plot(X,y_pred,color = '#A3E4D7', label='b=0')
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.01
epochs = 100
for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    b = b - (lr * loss_slope)
    y_pred = m*X +b
    plt.plot(X,y_pred)

plt.scatter(X,y)

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets = 1, noise=20,random_state=42)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [47.13323967]
# 2.3302306410539453

# %%
m = 47.13

# %%
class GDRegressor:
    def __init__(self,learning_rate,epochs):
        self.m = 47.13 
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
    def fit(self,X,y):
        for i in range(self.epochs):
            loss_slope = -2* np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr*loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -24465.97884252903 -95.53402115747096
# -19572.78307402322 -75.96123808344774
# -15658.226459218578 -60.30301162422916
# -12526.581167374861 -47.7764304568543
# -10021.264933899889 -37.755165522954414
# -8017.011947119913 -29.738153575834502
# -6413.60955769593 -23.324544018138575
# -5130.887646156745 -18.19365637198183
# -4104.710116925396 -14.088946255056435
# -3283.7680935403173 -10.805178161516118
# -2627.014474832253 -8.178163686683865
# -2101.611579865803 -6.0765521068180615
# -1681.2892638926426 -4.395262842925419
# -1345.0314111141138 -3.050231431811305
# -1076.0251288912907 -1.9742063029200143
# -860.8201031130328 -1.1133861998069814
# -688.6560824904262 -0.4247301173165552
# -550.9248659923411 0.12619474867578595
# -440.7398927938728 0.5669346414696588
# -352.59191423509833 0.9195265557047572
# -282.0735313880786 1.2016000870928358
# -225.65882511046289 1.4272589122032988
# -180.52706008837004 1.6077859722916688
# -144.42164807069614 1.7522076203623649
# -115.53731845655687 1.8677449388189218
# -92.42985476524547 1.9601747935841674
# -73.94388381219659 2.0341186773963638
# -59.15510704975709 2.093273784446121
# -47.32408563980571 2.1405978700859265
# -37.859268511844604 2.178457138597771
# -30.287414809475706 2.2087445534072465
# -24.22993184758063 2.232974485254827
# -19.383945478064476 2.2523584307328917
# -15.507156382451697 2.2678655871153435
# -12.405725105961181 2.2802713122213047
# -9.924580084768984 2.2901958923060737
# -7.939664067815251 2.298135556373889
# -6.351731254252151 2.3044872876281413
# -5.081385003401628 2.309568672631543
# -4.0651080027214235 2.3136337806342646
# -3.252086402176964 2.3168858670364414
# -2.6016691217417502 2.3194875361581833
# -2.0813352973932098 2.3215688714555767
# -1.6650682379146673 2.323233939693491
# -1.3320545903316585 2.3245659942838226
# -1.0656436722653595 2.325631637956088
# -0.8525149378123231 2.3264841528939004
# -0.6820119502497803 2.3271661648441504
# -0.5456095601998001 2.3277117744043503
# -0.4364876481599609 2.3281482620525105
# -0.3491901185277939 2.3284974521710384
# -0.2793520948221797 2.3287768042658605
# -0.22348167585773382 2.3290002859417185
# -0.178785340686332 2.3291790712824048
# -0.14302827254909545 2.329322099554954
# -0.11442261803909304 2.329436522172993
# -0.09153809443123606 2.329528060267424
# -0.07323047554502438 2.329601290742969
# -0.05858438043616587 2.329659875123405
# -0.04686750434897391 2.3297067426277542
# -0.03749400347913223 2.3297442366312335
# -0.02999520278315515 2.329774231834017
# -0.023996162226623596 2.3297982279962435
# -0.019196929781351457 2.329817424926025
# -0.015357543825011533 2.32983278246985
# -0.012286035059950962 2.32984506850491
# -0.009828828048036087 2.329854897332958
# -0.007863062438424606 2.3298627603953963
# -0.006290449950689947 2.329869050845347
# -0.005032359960615906 2.3298740832053078
# -0.0040258879683321425 2.329878109093276
# -0.0032207103746699772 2.329881329803651
# -0.0025765682997658246 2.3298839063719505
# -0.0020612546397345 2.3298859676265904
# -0.0016490037117833367 2.329887616630302
# -0.0013192029695474616 2.3298889358332717
# -0.0010553623756877073 2.3298899911956474
# -0.0008442899004634796 2.329890835485548
# -0.000675431920242886 2.3298915109174683
# -0.0005403455362085197 2.3298920512630046
# -0.00043227642900234287 2.3298924835394335
# -0.00034582114331271896 2.3298928293605767
# -0.00027665691451517205 2.3298931060174914
# -0.00022132553169029734 2.329893327343023
# -0.00017706042539344935 2.3298935044034486
# -0.00014164834026786366 2.3298936460517887
# -0.00011331867217023728 2.329893759370461
# -9.065493780013867e-05 2.3298938500253987
# -7.252395013068735e-05 2.3298939225493487
# -5.8019160157130045e-05 2.329893980568509
# -4.641532812144078e-05 2.329894026983837
# -3.7132262541206273e-05 2.3298940641160995
# -2.9705809971858343e-05 2.3298940938219093
# -2.376464801301381e-05 2.3298941175865573
# -1.901171842888516e-05 2.3298941365982757
# -1.5209374709002077e-05 2.3298941518076504
# -1.2167499953363858e-05 2.3298941639751503
# -9.733999810634941e-06 2.32989417370915
# -7.787199969300218e-06 2.32989418149635
# -6.2297599967564565e-06 2.3298941877261097
# 2.3298941877261097
